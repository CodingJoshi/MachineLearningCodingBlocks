# %% [markdown]
# # 1. Quick Start Python

# %%
a="hello World"
print(a)
# Out:
# hello World

# %%
# input in python
numbers=input();
print(numbers);
numbers_list_char=numbers.split();
print(numbers_list_char)
# Out:
# 1 2 3 4 5 6
# 1 2 3 4 5 6
# ['1', '2', '3', '4', '5', '6']

# %%
numbers_list_int=[int(x) for x in numbers_list_char]
print(numbers_list_int);
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
for i in numbers_list_int:
    if i==1:
        print("BUlbasur")
    elif i==3:
        print("charamendar")
    else :
        print("invalid");
# Out:
# BUlbasur
# invalid
# charamendar
# invalid
# invalid
# invalid

# %%
# Dictionary in Python
pokemon_map={
    1: "Bulbasaur",
    2: "Pikachu",
    3: "Charmendar"
}
print(pokemon_map[2])
# pokemon_map[5] #error comes best is to use get()

if pokemon_map.get(5) is None:
   print("Pokmon not found");
else:
    print(pokemon_map[5])
# Out:
# Pikachu
# Pokmon not found

# %%
for i in numbers_list_int:
    if pokemon_map.get(i) is None:
        print("Pokemon Not Found")
    else:
        print(pokemon_map[i])
# Out:
# Bulbasaur
# Pikachu
# Charmendar
# Pokemon Not Found
# Pokemon Not Found
# Pokemon Not Found

# %%
# list in python
pokemons=[("bulbasaur",200),("pikachu",250),("charmender",900,200)]
pokemons[0]=("bulbasaur",500);

for i in range(0,len(pokemons)):
    print(pokemons[i])
# Out:
# ('bulbasaur', 500)
# ('pikachu', 250)
# ('charmender', 900, 200)

# %%
# Tuples in python (Read only list)
t=("A","B","C")
for i in t :
    print(i,end=" ");
# Out:
# A B C

# %%
def PrintPokemons(numbers):
    #dictonary
    pokemon_map={
        1: "Bulbasaur",
        2: "Pikachu",
        3: "Charmendar"
    }
    #loop
    for i in numbers_list_int:
        if pokemon_map.get(i) is None:
            print("Pokemon Not Found")
        else:
            print(pokemon_map[i])
return ;

# %%
numbers=[ int(i) for i  in input().split()]
PrintPokemons(numbers)
# Out:
# 1 2 3 4 5 56
# Bulbasaur
# Pikachu
# Charmendar
# Pokemon Not Found
# Pokemon Not Found
# Pokemon Not Found

# %% [markdown]
# # 2. NUMPY Library

# %%
# !pip install numpy

# %%
import numpy as np

# %%
np.absolute(-5)
# Out:
# 5

# %%
#few Important Functions
a=np.array([1,2,3,4])
print(a);
print(type(a))
a.shape
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>
# (4,)

# %%
b=np.array([[1,2,3,4],[5,6,7,8]])
print(b);
print(b.shape)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]
# (2, 4)

# %%
b.T
# Out:
# array([[1, 5],
#        [2, 6],
#        [3, 7],
#        [4, 8]])

# %%
np.dot(b,b.T)
# Out:
# array([[ 30,  70],
#        [ 70, 174]])

# %%
np.random.randint(60,100,10)
np.
# Out:
# array([83, 81, 60, 81, 98, 78, 96, 78, 61, 92])

# %%
matrix=np.random.randint(60,100,(5,5))
print(matrix)
# Out:
# [[75 93 68 61 65]
#  [91 82 78 71 94]
#  [79 92 74 90 84]
#  [73 76 82 65 98]
#  [67 69 66 72 95]]

# %%
print(np.max(matrix))
print(np.min(matrix))
# Out:
# 98
# 61

# %%
a=np.array([0,1,4,4,-6,7,7,7,7,6,7,6,11])

# %%
np.argmin(a)
# Out:
# 4

# %%
b=np.unique(a,return_counts=True)
print(b)
# Out:
# (array([-6,  0,  1,  4,  6,  7, 11]), array([1, 1, 1, 2, 2, 5, 1]))

# %%
print(b[0])
print(b[1])
# Out:
# [-6  0  1  4  6  7 11]
# [1 1 1 2 2 5 1]

# %%
#wap to find out element with max freq
b=np.unique(a,return_counts=True);
print(b);
idx=np.argmax(b[1]);
ans=b[0][idx];
print(ans)
# Out:
# (array([-6,  0,  1,  4,  6,  7, 11]), array([1, 1, 1, 2, 2, 5, 1]))
# 7

# %%
# Slicing Arrays
print(matrix)
# Out:
# [[75 93 68 61 65]
#  [91 82 78 71 94]
#  [79 92 74 90 84]
#  [73 76 82 65 98]
#  [67 69 66 72 95]]

# %%
matrix[2:4,1:4]
# Out:
# array([[92, 74, 90],
#        [76, 82, 65]])

# %%
matrix[0][-1]
# Out:
# 65

# %% [markdown]
# # 3. Data Visualisation

# %%
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5])
y = x**2 + 3

# %%
print(x,y)
# Out:
# [1 2 3 4 5] [ 4  7 12 19 28]

# %%
plt.style.use('seaborn-darkgrid');
plt.title("My line plot")
plt.plot(x,x**2+x,label="stock Price")
plt.plot(x,x**2,label="stock Price")
plt.xlabel("TimeStamp")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
plt.style.available
# Out:
# ['seaborn-poster',
#  'seaborn-bright',
#  'classic',
#  'seaborn-whitegrid',
#  'fast',
#  'dark_background',
#  'seaborn',
#  'grayscale',
#  'seaborn-dark',
#  'seaborn-talk',
#  'seaborn-dark-palette',
#  'seaborn-ticks',
#  'ggplot',
#  'bmh',
#  'seaborn-darkgrid',
#  'seaborn-paper',
#  'seaborn-colorblind',
#  'tableau-colorblind10',
#  'seaborn-notebook',
#  'seaborn-muted',
#  '_classic_test',
#  'seaborn-deep',
#  'fivethirtyeight',
#  'seaborn-white',
#  'seaborn-pastel',
#  'Solarize_Light2']

# %%
plt.style.use('seaborn-darkgrid');
plt.title("My Scatter plot")
plt.scatter(x,x**2+x,label="stock Price")
plt.scatter(x,x**2,label="stock Price")
plt.xlabel("TimeStamp")
plt.ylabel("Price")
plt.legend()
plt.show()

# %% [markdown]
# # 4. Working with OpenCV & Images

# %%
import os
os.sys.path
#this is to check whether it takes correct path or not
# Out:
# ['/home/saurabh/Documents/MachineLearningCodingBlocks/QuickStartMode',
#  '/home/saurabh/anaconda3/lib/python37.zip',
#  '/home/saurabh/anaconda3/lib/python3.7',
#  '/home/saurabh/anaconda3/lib/python3.7/lib-dynload',
#  '',
#  '/home/saurabh/anaconda3/lib/python3.7/site-packages',
#  '/home/saurabh/anaconda3/lib/python3.7/site-packages/IPython/extensions',
#  '/home/saurabh/.ipython']

# %%
# !pip install opencv-python
# Out:
# ...
#      |████████████████████████████████| 28.2 MB 443 kB/s eta 0:00:01     |█████████████████████▍          | 18.8 MB 588 kB/s eta 0:00:16     |█████████████████████▉          | 19.2 MB 702 kB/s eta 0:00:13
# ...

# %%
import cv2

# %%
logo=cv2.imread('Logo.jpeg');

# %%
img=cv2.imread("TestImage.png")
print(img.shape)
# Out:
# (768, 1366, 3)

# %%
#to show image on jupyter
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(logo)

# it show img in BGR format but actually img is in RGB formate

# %%
rgb_image=cv2.cvtColor(logo,cv2.COLOR_BGR2RGB)

# %%
plt.style.use('seaborn-whitegrid')
plt.imshow(rgb_image)

# %%
crop_image=rgb_image[300:800,300:800,]
plt.imshow(crop_image)

# %%
crop_image.shape
# Out:
# (500, 500, 3)

# %%
total_pixels=crop_image.shape[0]*crop_image.shape[1]
print(total_pixels)

# each pixelhas 3 values hence total_pixel*3 integers reqiured
# Out:
# 250000

# %%
#Resize Image
crop_image=cv2.resize(crop_image,(100,100))
plt.title("bulbasaur"+str(crop_image.shape))
plt.imshow(crop_image)

# %% [markdown]
# # 5. Pandas - Working with Tablular Data

# %%
import numpy as np

# %%
import pandas as pd

# %%
pokemons={
    "Pokemon_Height" : np.random.randint(1,100,5),
    "Pokemon_Weight" : np.random.randint(50,150,5),
    "Pokemon_Power" : np.random.randint(200,250,5)
}

# %%
df= pd.DataFrame(pokemons)
print(df)
# Out:
#    Pokemon_Height  Pokemon_Weight  Pokemon_Power
# 0              54             130            231
# 1              78             120            227
# 2              24              65            238
# 3              46             138            222
# 4              28              72            246

# %%
df.head(3)
# Out:
#    Pokemon_Height  Pokemon_Weight  Pokemon_Power
# 0              54             130            231
# 1              78             120            227
# 2              24              65            238

# %%
print(df.columns)
# Out:
# Index(['Pokemon_Height', 'Pokemon_Weight', 'Pokemon_Power'], dtype='object')

# %%
# Create a CSV(Comma Seperate File) File 
df.to_csv('pokemon_data.csv',index=False)

# %% [markdown]
# ### Read a Data Frame

# %%
# -kaggle Challenges --> CSV files

df=pd.read_csv('pokemon_data.csv')

# %%
df.head()
# Out:
#    Pokemon_Height  Pokemon_Weight  Pokemon_Power
# 0              54             130            231
# 1              78             120            227
# 2              24              65            238
# 3              46             138            222
# 4              28              72            246

# %%
df.shape
# Out:
# (5, 3)

# %%
cum_sum=0;
l=[int(i) for i in input().split()]
for i in l:
    cum_sum+=i;
    if cum_sum<0:
        break;
    else :
        print(i);
# Out:
# 1 -2 -88 -42 -100
# 1
